# %% [markdown]
# ### Aniket Dutta, 172010007006,CSE,Barak Valley Engineering College

# %%
import numpy as np #n-dimensional array
import pandas as pd #data analysis and manipulation tool
import seaborn as sns #plotting graphs , histograms etc
import matplotlib.pyplot as plt #plotting charts,graphs etc
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
ani = pd.read_csv("dataset.csv") #loading data from dataset

# %%
ani.head() #prints starting 5 rows from the dataset
# Out:
#       START_DATE*       END_DATE*  ... MILES*         PURPOSE*
# 0  1/1/2016 21:11  1/1/2016 21:17  ...    5.1   Meal/Entertain
# 1   1/2/2016 1:25   1/2/2016 1:37  ...    5.0              NaN
# 2  1/2/2016 20:25  1/2/2016 20:38  ...    4.8  Errand/Supplies
# 3  1/5/2016 17:31  1/5/2016 17:45  ...    4.7          Meeting
# 4  1/6/2016 14:42  1/6/2016 15:49  ...   63.7   Customer Visit
#
# [5 rows x 7 columns]

# %%
ani.info() #displays all info/stats associated with the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
ani.isnull().sum() #empty values present
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
ani.tail() #prints the last 5 rows from the dataset
# Out:
#            START_DATE*         END_DATE*  ...   MILES*        PURPOSE*
# 1151  12/31/2016 13:24  12/31/2016 13:42  ...      3.9  Temporary Site
# 1152  12/31/2016 15:03  12/31/2016 15:38  ...     16.2         Meeting
# 1153  12/31/2016 21:32  12/31/2016 21:50  ...      6.4  Temporary Site
# 1154  12/31/2016 22:08  12/31/2016 23:51  ...     48.2  Temporary Site
# 1155            Totals               NaN  ...  12204.7             NaN
#
# [5 rows x 7 columns]

# %%
n_col = ani.select_dtypes(include= np.number).columns
print("Numerical column : ",n_col)   #prints all colums having number/numerical value

c_col = ani.select_dtypes(exclude= np.number).columns
print("Character column : ",c_col)    #prints all colums having character
# Out:
# Numerical column :  Index(['MILES*'], dtype='object')
# Character column :  Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'PURPOSE*'], dtype='object')

# %%
ani.drop(ani.tail(1).index, inplace=True) #dropping the last row since it has all null values and is not required

# %%
ani.isnull().sum()  #prints the sum of null values in rows
# Out:
# START_DATE*      0
# END_DATE*        0
# CATEGORY*        0
# START*           0
# STOP*            0
# MILES*           0
# PURPOSE*       502
# dtype: int64

# %%
sns.heatmap(ani.isnull(),yticklabels=False) #plot heatmap of the features using seaborn

# %%
ani.head()
# Out:
#       START_DATE*       END_DATE*  ... MILES*         PURPOSE*
# 0  1/1/2016 21:11  1/1/2016 21:17  ...    5.1   Meal/Entertain
# 1   1/2/2016 1:25   1/2/2016 1:37  ...    5.0              NaN
# 2  1/2/2016 20:25  1/2/2016 20:38  ...    4.8  Errand/Supplies
# 3  1/5/2016 17:31  1/5/2016 17:45  ...    4.7          Meeting
# 4  1/6/2016 14:42  1/6/2016 15:49  ...   63.7   Customer Visit
#
# [5 rows x 7 columns]

# %%
ani.describe() #prints all statistics associated with numerical columns
# Out:
#             MILES*
# count  1155.000000
# mean     10.566840
# std      21.579106
# min       0.500000
# 25%       2.900000
# 50%       6.000000
# 75%      10.400000
# max     310.300000

# %%
ani['START_DATE*']=ani['START_DATE*'].astype('datetime64[ns]')
ani['END_DATE*']=ani['END_DATE*'].astype('datetime64[ns]')

# %%
ani['Time'] = ani['END_DATE*']-ani['START_DATE*'] #find time required by substracting the two values
ani.head()
# Out:
#           START_DATE*           END_DATE*  ...         PURPOSE*     Time
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  ...   Meal/Entertain 00:06:00
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  ...              NaN 00:12:00
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  ...  Errand/Supplies 00:13:00
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  ...          Meeting 00:14:00
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  ...   Customer Visit 01:07:00
#
# [5 rows x 8 columns]

# %%
ani['Time'] = ani['Time'].dt.total_seconds()/60.0
ani['Time'] = ani['Time'].astype('float')
ani.head()
# Out:
#           START_DATE*           END_DATE*  ...         PURPOSE*  Time
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  ...   Meal/Entertain   6.0
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  ...              NaN  12.0
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  ...  Errand/Supplies  13.0
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  ...          Meeting  14.0
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  ...   Customer Visit  67.0
#
# [5 rows x 8 columns]

# %%
ani['KM']= ani['MILES*']*1.609 #converted miles to km for better understanding

# %%
ani.head()
# Out:
#           START_DATE*           END_DATE*  ...  Time        KM
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  ...   6.0    8.2059
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  ...  12.0    8.0450
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  ...  13.0    7.7232
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  ...  14.0    7.5623
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  ...  67.0  102.4933
#
# [5 rows x 9 columns]

# %%
ani.drop(['MILES*'],axis=1) #dropped miles since km is present
# Out:
#              START_DATE*           END_DATE*  ...   Time        KM
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  ...    6.0    8.2059
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  ...   12.0    8.0450
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  ...   13.0    7.7232
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  ...   14.0    7.5623
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  ...   67.0  102.4933
# ...                  ...                 ...  ...    ...       ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  ...    7.0    1.1263
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  ...   18.0    6.2751
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  ...   35.0   26.0658
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  ...   18.0   10.2976
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  ...  103.0   77.5538
#
# [1155 rows x 8 columns]

# %%
ani['speed']=(ani['KM']/ani['Time'])*60 #time:min & speed:kmph

# %%
ani.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*  ...  Time        KM      speed
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  ...   6.0    8.2059  82.059000
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  ...  12.0    8.0450  40.225000
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  ...  13.0    7.7232  35.645538
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  ...  14.0    7.5623  32.409857
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  ...  67.0  102.4933  91.785045
#
# [5 rows x 10 columns]

# %%
ani.tail()
# Out:
#              START_DATE*           END_DATE*  ...       KM      speed
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  ...   1.1263   9.654000
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  ...   6.2751  20.917000
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  ...  26.0658  44.684229
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  ...  10.2976  34.325333
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  ...  77.5538  45.176971
#
# [5 rows x 10 columns]

# %%
#HOUR DAY TRANSFORMATION

# %%
import datetime
import calendar

# %%
ani['START_DATE*'] = pd.to_datetime(ani['START_DATE*'], format="%m/%d/%Y %H:%M") 
ani['END_DATE*'] = pd.to_datetime(ani['END_DATE*'], format="%m/%d/%Y %H:%M")

# %%
hour=[]  #empty list
day=[]
dayofweek=[]
month=[]
weekday=[]
for x in ani['START_DATE*']:
    hour.append(x.hour) #adding/appending the values to above empty list
    day.append(x.day)
    dayofweek.append(x.dayofweek)
    month.append(x.month)
    weekday.append(calendar.day_name[dayofweek[-1]])
ani['HOUR']=hour #creatig columns
ani['DAY']=day
ani['DAY_OF_WEEK']=dayofweek
ani['MONTH']=month
ani['WEEKDAY']=weekday

# %%
ani.head() #updated dataset
# Out:
#           START_DATE*           END_DATE*  ... MONTH    WEEKDAY
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  ...     1     Friday
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  ...     1   Saturday
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  ...     1   Saturday
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  ...     1    Tuesday
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  ...     1  Wednesday
#
# [5 rows x 15 columns]

# %%
ani['HOUR'].value_counts().plot(kind='bar',figsize=(10,5),color='red') #trips per hour

# %%
ani['WEEKDAY'].value_counts().plot(kind='bar',figsize=(10,5),color='black') #trips per day of week

# %%
ani['DAY'].value_counts().plot(kind='bar',figsize=(10,5),color='blue') #trips per day of the month

# %%
ani['MONTH'].value_counts().plot(kind='bar',figsize=(10,5),color='green') #trips in month, month 12 has highest number of trips as depicted in the figure

# %%
ani.groupby('PURPOSE*').mean().plot(kind='bar',figsize=(10,5)) #overall analysis
